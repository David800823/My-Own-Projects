# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("vfnx-vebw", limit=4000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
pd.set_option("display.max_columns", None)

results_df.head(1)
# Out:
#                    x                 y unique_squirrel_id hectare shift  \
# 0  -73.9561344937861  40.7940823884086     37F-PM-1014-03     37F    PM
#
#        date hectare_squirrel_number combination_of_primary_and  running  \
# 0  10142018                       3                          +    False
#
#    chasing  climbing  eating  foraging   kuks  quaas  moans  tail_flags  \
# 0    False     False   False     False  False  False  False       False
#
#    tail_twitches  approaches  indifferent  runs_from  \
# 0          False       False        False      False
#
#                                      geocoded_column  \
# 0  {'type': 'Point', 'coordinates': [-73.95613449...
#
#   :@computed_region_f5dn_yrer :@computed_region_yeji_bk3q  \
# 0                          19                           4
#
#   :@computed_region_92fq_4b7q :@computed_region_sbqj_enih primary_fur_color  \
# 0                          19                          13               NaN
#
# ...

# %%
squirrel = results_df.drop(columns = ["geocoded_column",":@computed_region_f5dn_yrer", ":@computed_region_yeji_bk3q",
                           ":@computed_region_92fq_4b7q",":@computed_region_sbqj_enih",":@computed_region_efsh_h5xi"])

# %%
squirrel.head(1)
# Out:
#                    x                 y unique_squirrel_id hectare shift  \
# 0  -73.9561344937861  40.7940823884086     37F-PM-1014-03     37F    PM
#
#        date hectare_squirrel_number combination_of_primary_and  running  \
# 0  10142018                       3                          +    False
#
#    chasing  climbing  eating  foraging   kuks  quaas  moans  tail_flags  \
# 0    False     False   False     False  False  False  False       False
#
#    tail_twitches  approaches  indifferent  runs_from primary_fur_color  \
# 0          False       False        False      False               NaN
#
#   location above_ground_sighter  age color_notes highlight_fur_color  \
# 0      NaN                  NaN  NaN         NaN                 NaN
#
#   specific_location other_activities other_interactions
# 0               NaN              NaN                NaN

# %%
colum_list = []

for col in squirrel.columns:
    colum_list.append(col)

# %%
print(colum_list)
# Out:
# ['x', 'y', 'unique_squirrel_id', 'hectare', 'shift', 'date', 'hectare_squirrel_number', 'combination_of_primary_and', 'running', 'chasing', 'climbing', 'eating', 'foraging', 'kuks', 'quaas', 'moans', 'tail_flags', 'tail_twitches', 'approaches', 'indifferent', 'runs_from', 'primary_fur_color', 'location', 'above_ground_sighter', 'age', 'color_notes', 'highlight_fur_color', 'specific_location', 'other_activities', 'other_interactions']

# %%
colum_list2 = ['shift', 'hectare_squirrel_number', 'running', 'chasing', 'climbing', 'eating', 'foraging', 'kuks', 'quaas', 'moans', 'tail_flags', 'tail_twitches', 'approaches', 'indifferent', 'runs_from', 'primary_fur_color', 'location', 'above_ground_sighter', 'age']

# %%
for columns in colum_list2:
    print(columns)
    print(results_df[columns].unique())
# Out:
# shift
# ['PM' 'AM']
# hectare_squirrel_number
# ['3' '4' '8' '14' '5' '2' '1' '6' '9' '23' '7' '13' '10' '16' '11' '12'
#  '20' '15' '19' '17' '21' '22' '18']
# running
# [False  True]
# chasing
# [False  True]
# climbing
# [False  True]
# eating
# [False  True]
# foraging
# [False  True]
# kuks
# [False  True]
# quaas
# [False  True]
# moans
# [False  True]
# tail_flags
# [False  True]
# tail_twitches
# [False  True]
# approaches
# [False  True]
# indifferent
# [False  True]
# runs_from
# [False  True]
# primary_fur_color
# [nan 'Gray' 'Cinnamon' 'Black']
# location
# [nan 'Above Ground' 'Ground Plane']
# above_ground_sighter
# [nan '10' 'FALSE' '30' '6' '24' '8' '25' '5' '50' '4' '3' '70' '12' '2'
#  '20' '7' '13' '15' '28' '35' '100' '1' '80' '65' '40' '18' '17' '55' '60'
#  '180' '9' '45' '0' '43' '16' '33' '11' '23' '31' '14' '19']
# age
# [nan 'Adult' 'Juvenile' '?']
